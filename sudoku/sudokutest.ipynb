# %%
# %run sudoku.py3.numpy.py
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/liuqun/Dropbox/Programing & Codes 编程与代码/PythonExercises/sudoku.py3.numpy.py in <module>()
#     463             [3,0,5,0,0,6,7,0,4],\
#     464             [0,0,7,4,3,9,0,5,8]])
# --> 465     sudoku2=sudoku("794386020638000749215947836,073600098,900803467,08607901,80976005,30009867,067030984")
#     466     sudoku3=sudoku("000500260305000004090001000020040600000012005900830000000700100800000047057009000")
#     467     sudoku4=sudoku("600000017 400001600 001000000 000010970 310800064 062004001 108097046 000000100 200100705")
#
# /Users/liuqun/Dropbox/Programing & Codes 编程与代码/PythonExercises/sudoku.py3.numpy.py in __init__(self, initial_board, solution_number_limit)
#      81                 for ch in line:
#      82                     if ch.isdigit():
# ---> 83                         if len(self.board[-1])==9:
# ...

# %%
sudokua.solve()
# Out:
# input:
# row 1 :    ---  7--  8--
# row 2 :    ---  -4-  -3-
# row 3 :    ---  --9  --1
#
# row 4 :    6--  5--  ---
# row 5 :    -1-  -3-  -4-
# row 6 :    --5  --1  --7
#
# row 7 :    5--  2--  6--
# row 8 :    -3-  -8-  -9-
# row 9 :    --7  ---  --2
#
# board :     000700800 000040030 000009001 600500000 010030040 005001007 500200600 030080090 007000002
#
# Try: [1,1]=1
# Try: [1,2]=2
# Update column set [5, 8] by row set [1, 6] using 6
# Fail!
# Try: [1,2]=4
# Try: [1,3]=2
# Fail!
# Try: [1,3]=3
# Fail!
# Try: [1,3]=6
# Fail!
# Try: [1,3]=9
# Fail!
# Try: [1,2]=5
# Fail!
# Try: [1,2]=6
# Fail!
# Try: [1,2]=9
# Try: [1,3]=2
# Fail!
# Try: [1,3]=3
# Fail!
# Try: [1,3]=4
# Fail!
# Try: [1,3]=6
# Fail!
# Try: [1,1]=2
# Update column set [6, 7] by row set [2, 5] using 2
# Try: [1,2]=4
# Try: [1,3]=1
# Fail!
# Try: [1,3]=3
# Fail!
# Try: [1,3]=6
# Fail!
# Try: [1,3]=9
# Fail!
# Try: [1,2]=5
# Fail!
# Try: [1,2]=9
# Try: [1,3]=1
# Fail!
# Try: [1,3]=3
# Fail!
# Try: [1,3]=4
# Fail!
# ...
